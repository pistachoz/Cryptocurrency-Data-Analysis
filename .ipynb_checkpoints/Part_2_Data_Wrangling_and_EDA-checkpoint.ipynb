# %%
# load EDA Packages
import pandas as pd
import numpy as np

# load data vizualization packages
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# other libraries for visualization
import matplotlib.dates as mdates
import matplotlib.ticker as mtick
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import iplot
import plotly.io as pio


# load web scrapping packages
import requests
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen
import os

# %% [markdown]
# # Assessing the Data

# %%
# read the various crypto currencies from their csv files
coin_btc = pd.read_csv('btc.csv')
coin_eth = pd.read_csv('eth.csv')
coin_ada = pd.read_csv('ada.csv')
coin_xrp = pd.read_csv('xrp.csv')
coin_usdt = pd.read_csv('usdt.csv')
coin_matic = pd.read_csv('matic.csv')
coin_usdc = pd.read_csv('usdc.csv')
coin_shib = pd.read_csv('shib.csv')
coin_ftm = pd.read_csv('ftm.csv')
coin_uma = pd.read_csv('uma.csv')

# %%
# loading the btc coin data again into a pandas dataframe
coin_btc
# Out:
#                 CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0     2018-09-01 00:00:00    7042.95    7101.03   6998.87     7017.35
# 1     2018-09-01 06:00:00    7015.78    7070.00   7015.22     7042.34
# 2     2018-09-01 12:00:00    7035.04    7131.85   7024.51     7058.97
# 3     2018-09-01 18:00:00    7058.97    7230.00   7021.29     7196.27
# 4     2018-09-02 00:00:00    7193.30    7300.18   7169.99     7185.01
# ...                   ...        ...        ...       ...         ...
# 5848  2022-09-02 00:00:00   19723.00   20174.00  19702.00    20128.00
# 5849  2022-09-02 06:00:00   20133.00   20295.00  19957.00    20125.00
# 5850  2022-09-02 12:00:00   20121.00   20159.00  19989.00    20086.00
# 5851  2022-09-02 18:00:00   20092.00   20440.00  19767.00    19809.00
# 5852  2022-09-03 00:00:00   19799.00   20068.00  19762.00    19932.00
#
#            volume     MarketCap
# 0     1353.671600  9.549478e+06
# 1      338.595700  2.384278e+06
# 2      874.048000  6.180810e+06
# 3     1570.716700  1.124772e+07
# 4     1807.095200  1.305408e+07
# ...           ...           ...
# 5848   476.355577  9.537266e+06
# 5849   316.406617  6.367552e+06
# 5850   233.874849  4.695775e+06
# 5851   819.956445  1.653837e+07
# 5852   257.761883  5.131508e+06
#
# [5853 rows x 7 columns]

# %%
# assign new column to the individual dataframes
coin_btc['Symbol'] = 'BTC'
coin_eth['Symbol'] = 'ETH'
coin_ada['Symbol'] = 'ADA'
coin_xrp['Symbol'] = 'XRP'
coin_usdt['Symbol'] = 'USDT'
coin_matic['Symbol'] = 'MATIC'
coin_usdc['Symbol'] = 'USDC'
coin_shib['Symbol'] = 'SHIB'
coin_ftm['Symbol'] = 'FTM'
coin_uma['Symbol'] = 'UMA'

# %%
# use the btc dataframe to confirm the new column
coin_btc
# Out:
#                 CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0     2018-09-01 00:00:00    7042.95    7101.03   6998.87     7017.35
# 1     2018-09-01 06:00:00    7015.78    7070.00   7015.22     7042.34
# 2     2018-09-01 12:00:00    7035.04    7131.85   7024.51     7058.97
# 3     2018-09-01 18:00:00    7058.97    7230.00   7021.29     7196.27
# 4     2018-09-02 00:00:00    7193.30    7300.18   7169.99     7185.01
# ...                   ...        ...        ...       ...         ...
# 5848  2022-09-02 00:00:00   19723.00   20174.00  19702.00    20128.00
# 5849  2022-09-02 06:00:00   20133.00   20295.00  19957.00    20125.00
# 5850  2022-09-02 12:00:00   20121.00   20159.00  19989.00    20086.00
# 5851  2022-09-02 18:00:00   20092.00   20440.00  19767.00    19809.00
# 5852  2022-09-03 00:00:00   19799.00   20068.00  19762.00    19932.00
#
#            volume     MarketCap Symbol
# 0     1353.671600  9.549478e+06    BTC
# 1      338.595700  2.384278e+06    BTC
# 2      874.048000  6.180810e+06    BTC
# 3     1570.716700  1.124772e+07    BTC
# 4     1807.095200  1.305408e+07    BTC
# ...           ...           ...    ...
# 5848   476.355577  9.537266e+06    BTC
# 5849   316.406617  6.367552e+06    BTC
# 5850   233.874849  4.695775e+06    BTC
# 5851   819.956445  1.653837e+07    BTC
# 5852   257.761883  5.131508e+06    BTC
#
# [5853 rows x 8 columns]

# %%
crypto = [coin_btc, coin_eth, coin_ada, coin_xrp, coin_usdt, coin_matic, coin_usdc, coin_shib, 
                          coin_ftm, coin_uma]

# %%
crypto_main = pd.concat(crypto, axis=0)

# %%
# convert the merged data to a dataframe and save to a csv file
pd.DataFrame.to_csv(crypto_main, 'crypto_main', index=False)

# %%
dff = pd.read_csv('crypto_main')
dff
# Out:
#                  CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0      2021-04-20 10:00:00   54461.85   55479.62  54284.33    54940.10
# 1      2021-04-20 12:00:00   54940.10   56466.32  54884.22    56348.13
# 2      2021-04-20 14:00:00   56356.72   56403.98  55661.65    56379.84
# 3      2021-04-20 16:00:00   56406.02   56542.92  54700.00    55355.58
# 4      2021-04-20 18:00:00   55384.65   56010.61  55155.76    55942.70
# ...                    ...        ...        ...       ...         ...
# 43742  2022-08-31 20:00:00       2.72       2.75      2.72        2.75
# 43743  2022-09-01 02:00:00       2.78       2.78      2.78        2.78
# 43744  2022-09-01 06:00:00       2.75       2.75      2.75        2.75
# 43745  2022-09-01 08:00:00       2.71       2.71      2.71        2.71
# 43746  2022-09-01 14:00:00       2.72       2.72      2.72        2.72
#
#            volume     MarketCap Symbol
# 0      420.173397  2.311098e+07    BTC
# 1      524.660874  2.932419e+07    BTC
# 2      408.564245  2.290104e+07    BTC
# 3      646.185067  3.587516e+07    BTC
# 4      386.479547  2.148352e+07    BTC
# ...           ...           ...    ...
# 43742   51.000447  1.390095e+02    UMA
# 43743   96.147878  2.672911e+02    UMA
# 43744   52.393939  1.440833e+02    UMA
# 43745  148.532765  4.025238e+02    UMA
# 43746    9.551507  2.598010e+01    UMA
#
# [43747 rows x 8 columns]

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43747 entries, 0 to 43746
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CloseTime   43747 non-null  object
#  1   OpenPrice   43747 non-null  float64
#  2   HighPrice   43747 non-null  float64
#  3   LowPrice    43747 non-null  float64
#  4   ClosePrice  43747 non-null  float64
#  5   volume      43747 non-null  float64
#  6   MarketCap   43747 non-null  float64
#  7   Symbol      43747 non-null  object
# dtypes: float64(6), object(2)
# memory usage: 2.7+ MB

# %%
# Convert CloseTime Column to datetime
dff['CloseTime'] = pd.to_datetime(dff['CloseTime'])

# extract year and month intto seperate columns
dff['Date'] = pd.to_datetime(dff['CloseTime']).dt.date
dff['Year'] = pd.to_datetime(dff['CloseTime']).dt.year
dff['Month'] = pd.to_datetime(dff['CloseTime']).dt.month

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43747 entries, 0 to 43746
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CloseTime   43747 non-null  datetime64[ns]
#  1   OpenPrice   43747 non-null  float64
#  2   HighPrice   43747 non-null  float64
#  3   LowPrice    43747 non-null  float64
#  4   ClosePrice  43747 non-null  float64
#  5   volume      43747 non-null  float64
#  6   MarketCap   43747 non-null  float64
#  7   Symbol      43747 non-null  object
#  8   Date        43747 non-null  object
#  9   Year        43747 non-null  int64
#  10  Month       43747 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(2)
# memory usage: 3.7+ MB

# %%
dff
# Out:
#                 CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0     2021-04-20 10:00:00   54461.85   55479.62  54284.33    54940.10
# 1     2021-04-20 12:00:00   54940.10   56466.32  54884.22    56348.13
# 2     2021-04-20 14:00:00   56356.72   56403.98  55661.65    56379.84
# 3     2021-04-20 16:00:00   56406.02   56542.92  54700.00    55355.58
# 4     2021-04-20 18:00:00   55384.65   56010.61  55155.76    55942.70
# ...                   ...        ...        ...       ...         ...
# 43742 2022-08-31 20:00:00       2.72       2.75      2.72        2.75
# 43743 2022-09-01 02:00:00       2.78       2.78      2.78        2.78
# 43744 2022-09-01 06:00:00       2.75       2.75      2.75        2.75
# 43745 2022-09-01 08:00:00       2.71       2.71      2.71        2.71
# 43746 2022-09-01 14:00:00       2.72       2.72      2.72        2.72
#
#            volume     MarketCap Symbol        Date  Year  Month
# 0      420.173397  2.311098e+07    BTC  2021-04-20  2021      4
# 1      524.660874  2.932419e+07    BTC  2021-04-20  2021      4
# 2      408.564245  2.290104e+07    BTC  2021-04-20  2021      4
# 3      646.185067  3.587516e+07    BTC  2021-04-20  2021      4
# 4      386.479547  2.148352e+07    BTC  2021-04-20  2021      4
# ...           ...           ...    ...         ...   ...    ...
# 43742   51.000447  1.390095e+02    UMA  2022-08-31  2022      8
# 43743   96.147878  2.672911e+02    UMA  2022-09-01  2022      9
# 43744   52.393939  1.440833e+02    UMA  2022-09-01  2022      9
# 43745  148.532765  4.025238e+02    UMA  2022-09-01  2022      9
# 43746    9.551507  2.598010e+01    UMA  2022-09-01  2022      9
#
# [43747 rows x 11 columns]

# %%
dff['Year'].unique()
# Out:
# array([2021, 2022], dtype=int64)

# %%
# merge the different crypto coins dataframes into one master dataframe
coins = pd.concat([coin_btc, coin_eth, coin_ada, coin_xrp, coin_usdt, coin_matic, coin_usdc, coin_shib, coin_ftm, coin_uma], axis = 0)
coins.head()
# Out:
#              CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0  2021-04-20 10:00:00   54461.85   55479.62  54284.33    54940.10
# 1  2021-04-20 12:00:00   54940.10   56466.32  54884.22    56348.13
# 2  2021-04-20 14:00:00   56356.72   56403.98  55661.65    56379.84
# 3  2021-04-20 16:00:00   56406.02   56542.92  54700.00    55355.58
# 4  2021-04-20 18:00:00   55384.65   56010.61  55155.76    55942.70
#
#        volume     MarketCap Symbol
# 0  420.173397  2.311098e+07    BTC
# 1  524.660874  2.932419e+07    BTC
# 2  408.564245  2.290104e+07    BTC
# 3  646.185067  3.587516e+07    BTC
# 4  386.479547  2.148352e+07    BTC

# %%
# combine the list of dataframes for merging
df_coins = [coin_btc, coin_eth, coin_ada, coin_xrp, coin_usdt, coin_matic, coin_usdc, coin_shib, 
                          coin_ftm, coin_uma]

# %%
# merge all the individual dataframes
crypto_coins = pd.concat(df_coins)

# %%
# convert the merged data to a dataframe and save to a csv file
pd.DataFrame.to_csv(crypto_coins, 'crypto_coins', index=False)

# %%
coins = pd.read_csv('crypto_coins')
coins
# Out:
#                  CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0      2018-09-01 00:00:00    7042.95    7101.03   6998.87     7017.35
# 1      2018-09-01 06:00:00    7015.78    7070.00   7015.22     7042.34
# 2      2018-09-01 12:00:00    7035.04    7131.85   7024.51     7058.97
# 3      2018-09-01 18:00:00    7058.97    7230.00   7021.29     7196.27
# 4      2018-09-02 00:00:00    7193.30    7300.18   7169.99     7185.01
# ...                    ...        ...        ...       ...         ...
# 23147  2022-09-01 12:00:00       2.71       2.71      2.71        2.71
# 23148  2022-09-01 18:00:00       2.72       2.72      2.72        2.72
# 23149  2022-09-02 12:00:00       2.75       2.75      2.75        2.75
# 23150  2022-09-02 18:00:00       2.72       2.84      2.71        2.80
# 23151  2022-09-03 00:00:00       2.79       2.79      2.79        2.79
#
#             volume     MarketCap Symbol
# 0      1353.671600  9.549478e+06    BTC
# 1       338.595700  2.384278e+06    BTC
# 2       874.048000  6.180810e+06    BTC
# 3      1570.716700  1.124772e+07    BTC
# 4      1807.095200  1.305408e+07    BTC
# ...            ...           ...    ...
# 23147   148.532765  4.025238e+02    UMA
# 23148     9.551507  2.598010e+01    UMA
# 23149    59.979287  1.649430e+02    UMA
# 23150    79.257187  2.220324e+02    UMA
# 23151     9.551507  2.664870e+01    UMA
#
# [23152 rows x 8 columns]

# %%
# check the number of columns and rows 
coins.shape
# Out:
# (23152, 8)

# %%
# check the dataframe information
coins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23152 entries, 0 to 23151
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CloseTime   23152 non-null  object
#  1   OpenPrice   23152 non-null  float64
#  2   HighPrice   23152 non-null  float64
#  3   LowPrice    23152 non-null  float64
#  4   ClosePrice  23152 non-null  float64
#  5   volume      23152 non-null  float64
#  6   MarketCap   23152 non-null  float64
#  7   Symbol      23152 non-null  object
# dtypes: float64(6), object(2)
# memory usage: 1.4+ MB

# %%
# check the statistical information of our dataframe
coins.describe()
# Out:
#           OpenPrice     HighPrice      LowPrice    ClosePrice        volume  \
# count  23152.000000  23152.000000  23152.000000  23152.000000  2.315200e+04
# mean    5850.329432   5931.368374   5760.113150   5850.742380  3.682522e+06
# std    13307.250008  13492.812648  13098.193906  13307.517640  1.062696e+07
# min        0.000041      0.000041      0.000041      0.000041  1.623158e+00
# 25%        0.732835      0.745910      0.715677      0.732698  1.624560e+03
# 50%        1.053775      1.073145      1.030905      1.051605  3.793926e+04
# 75%     3867.847500   3916.440000   3832.237500   3868.480000  1.574897e+06
# max    68635.050000  69000.000000  67342.010000  68627.010000  3.397379e+08
#
#           MarketCap
# count  2.315200e+04
# mean   9.447002e+06
# std    2.174346e+07
# min    6.932931e+00
# 25%    9.953397e+04
# 50%    1.843026e+06
# 75%    9.388807e+06
# max    5.151514e+08

# %%
# checking for missing valuses in our dataframe
coins.isnull().sum()
# Out:
# CloseTime     0
# OpenPrice     0
# HighPrice     0
# LowPrice      0
# ClosePrice    0
# volume        0
# MarketCap     0
# Symbol        0
# dtype: int64

# %%
# checking for duplicate values in our dataframe
coins.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Observations
#
# Quality issue:
#  - CloseTime column is in object type instead of datetime

# %% [markdown]
# # Data Cleaning

# %%
# Convert CloseTime Column to datetime
coins['CloseTime'] = pd.to_datetime(coins['CloseTime'])

# extract year and month intto seperate columns
coins['Date'] = pd.to_datetime(coins['CloseTime']).dt.date
coins['Year'] = pd.to_datetime(coins['CloseTime']).dt.year
coins['Month'] = pd.to_datetime(coins['CloseTime']).dt.month

# %% [markdown]
# # Exploratory Data Analysis

# %%
coins
# Out:
#                 CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0     2018-09-01 00:00:00    7042.95    7101.03   6998.87     7017.35
# 1     2018-09-01 06:00:00    7015.78    7070.00   7015.22     7042.34
# 2     2018-09-01 12:00:00    7035.04    7131.85   7024.51     7058.97
# 3     2018-09-01 18:00:00    7058.97    7230.00   7021.29     7196.27
# 4     2018-09-02 00:00:00    7193.30    7300.18   7169.99     7185.01
# ...                   ...        ...        ...       ...         ...
# 23147 2022-09-01 12:00:00       2.71       2.71      2.71        2.71
# 23148 2022-09-01 18:00:00       2.72       2.72      2.72        2.72
# 23149 2022-09-02 12:00:00       2.75       2.75      2.75        2.75
# 23150 2022-09-02 18:00:00       2.72       2.84      2.71        2.80
# 23151 2022-09-03 00:00:00       2.79       2.79      2.79        2.79
#
#             volume     MarketCap Symbol        Date  Year  Month
# 0      1353.671600  9.549478e+06    BTC  2018-09-01  2018      9
# 1       338.595700  2.384278e+06    BTC  2018-09-01  2018      9
# 2       874.048000  6.180810e+06    BTC  2018-09-01  2018      9
# 3      1570.716700  1.124772e+07    BTC  2018-09-01  2018      9
# 4      1807.095200  1.305408e+07    BTC  2018-09-02  2018      9
# ...            ...           ...    ...         ...   ...    ...
# 23147   148.532765  4.025238e+02    UMA  2022-09-01  2022      9
# 23148     9.551507  2.598010e+01    UMA  2022-09-01  2022      9
# 23149    59.979287  1.649430e+02    UMA  2022-09-02  2022      9
# 23150    79.257187  2.220324e+02    UMA  2022-09-02  2022      9
# 23151     9.551507  2.664870e+01    UMA  2022-09-03  2022      9
#
# [23152 rows x 11 columns]

# %% [markdown]
# ## Univariate Analysis

# %%
color = sb.color_palette()[0]
sb.countplot(data=coins, x = 'Symbol', color=color)
plt.xlabel('Coins')
plt.ylabel('Count')
plt.title('Distribution of the Different Coins');

# %%
# let's get the value count of each coin in a dataframe
print(pd.DataFrame(coins['Symbol'].value_counts()))

# let's get the percentage of each coin count
print(pd.DataFrame(coins['Symbol'].value_counts(normalize=True)*100))
# Out:
#        Symbol
# BTC      5853
# XRP      5853
# USDC     2725
# UMA      1886
# USDT     1777
# MATIC    1555
# ETH      1500
# ADA      1128
# FTM       874
# SHIB        1
#           Symbol
# BTC    25.280753
# XRP    25.280753
# USDC   11.770041
# UMA     8.146164
# USDT    7.675363
# MATIC   6.716482
# ETH     6.478922
# ADA     4.872149
# FTM     3.775052
# SHIB    0.004319

# %%
# start with a standard-scaled plot
#plt.figure(figsize=[17, 13])

#plt.subplot(2,2,1)
plt.figure(figsize=[8, 7])

binsize = 200
bins = np.arange(0.000020, coins['OpenPrice'].max()+binsize, binsize)
plt.hist(data=coins, x='OpenPrice', bins = bins)
plt.title('Distribution of Open Prices of the coins')
# Out:
# Text(0.5, 1.0, 'Distribution of Open Prices of the coins')

# %%
coins['OpenPrice'].max()
# Out:
# 68635.05

# %%
coins['OpenPrice'].min()
# Out:
# 4.1e-05

# %%
coins['OpenPrice'].describe()
# Out:
# count    23152.000000
# mean      5850.329432
# std      13307.250008
# min          0.000041
# 25%          0.732835
# 50%          1.053775
# 75%       3867.847500
# max      68635.050000
# Name: OpenPrice, dtype: float64

# %%
np.log10(coins['OpenPrice'].describe())
# Out:
# count    4.364589
# mean     3.767180
# std      4.124088
# min     -4.387216
# 25%     -0.134994
# 50%      0.022748
# 75%      3.587469
# max      4.836546
# Name: OpenPrice, dtype: float64

# %%
#there's a long tail in the distribution, so let's put it on a log scale instead
plt.figure(figsize=[8, 7])
log_binsize = 0.1
bins = 10 ** np.arange(-1, np.log10(coins['OpenPrice'].max())+log_binsize, log_binsize)
ticks =[1, 4, 10, 40, 1000, 10000, 20000, 30000, 40000, 50000, 60000, 70000]
label = ['{}'.format(v) for v in ticks]
plt.hist(data = coins, x = 'OpenPrice', bins=bins)
plt.xscale('log')
plt.title('Distribution of Open Prices of the coins');

# %%
# there's a long tail in the distribution, so let's put it on a log scale instead
plt.figure(figsize=[8, 7])
log_binsize = 0.1
bins = 10 ** np.arange(0, np.log10(coins['OpenPrice'].max())+log_binsize, log_binsize)
ticks =[1, 4, 10, 40, 1000, 10000, 20000, 30000, 40000, 50000, 60000, 70000]
label = ['{}'.format(v) for v in ticks]
plt.hist(data = coins, x = 'OpenPrice', bins=bins)
plt.xscale('log')

# %%
# there's a long tail in the distribution, so let's put it on a log scale instead
plt.figure(figsize=[8, 7])
log_binsize = 0.1
bins = 10 ** np.arange(-1, 4 + 0.1, 0.1)
ticks =[1, 4, 10, 40, 1000, 10000, 20000, 30000, 40000, 50000, 60000, 70000 ]
labels = ['{}'.format(v) for v in ticks]
plt.hist(data = coins, x = 'OpenPrice', bins=bins)
plt.xscale('log')
plt.title('Distribution of Open Prices of the coins');

# %%
# there's a long tail in the distribution, so let's put it on a log scale instead
plt.figure(figsize=[8, 7])
log_binsize = 0.1
bins = 10 ** np.arange(0, np.log10(coins['OpenPrice'].max())+log_binsize, log_binsize)
#ticks =[1, 4, 10, 40, 1000, 10000, 20000, 30000, 40000, 50000, 60000, 70000]
label = ['{}'.format(v) for v in ticks]
plt.hist(data = coins, x = 'OpenPrice', bins=bins)
plt.xscale('log')
plt.xticks([1, 10, 1000, 10000, 20000, 30000, 40000, 50000, 60000, 70000],
          [1, 10, '1k', '10k', '20k', '30k', '40k', '50k', '60k', '70k']);

# %%
coins['s']

# %% [markdown]
# ## Bivariate Analysis

# %%
# Finding top 5 cryptocurrencies by market cap
plt.figure(figsize=[18,5])
ax = coins.groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(5).sort_values().plot(kind='barh')
ax.set_xlabel('Market Cap (in billion USD)')
ax.ticklabel_format(style='plain', axis='x')
plt.title('Top 5 Cryptocurrencies by Market Cap', fontsize = 15)
plt.show()

# %% [markdown]
# We can observe from the above grapg that Bitcoin has the highest market cap and etherium is a bit more than 50% of it, and Matic being the coin with the least market cap.

# %%
# Plotting graphs of closing prices of top 4 Cryptocurrencies as Per Market Cap

# %%
dx = coins.copy()

top_4_currency_names = dx.groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(4).index
top_4_currency_names_except_first = dx[dx['Symbol']!= 'BTC'].groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(4).index
top_4_currency_names_except_first_two = dx[(dx['Symbol']!= 'BTC') & (dx['Symbol']!= 'ETH')].groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(4).index
top_4_currency_names_except_first_two_three = dx[(dx['Symbol']!= 'BTC') & (dx['Symbol']!= 'ETH') & (dx['Symbol']!= 'USDT')].groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(4).index

data_top_4_currencies = dx[dx['Symbol'].isin(top_4_currency_names)]
top_4_currencies_after_BTC = dx[dx['Symbol'].isin(top_4_currency_names_except_first)]
top_4_currencies_after_BTC_ETH = dx[dx['Symbol'].isin(top_4_currency_names_except_first_two)]
top_4_currencies_after_BTC_ETH_USDT = dx[dx['Symbol'].isin(top_4_currency_names_except_first_two_three)]

# %%
dx = dff.copy()

top_4_currency_names = dx.groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(4).index
top_4_currency_names_except_first = dx[dx['Symbol']!= 'BTC'].groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(4).index
top_4_currency_names_except_first_two = dx[(dx['Symbol']!= 'BTC') & (dx['Symbol']!= 'ETH')].groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(4).index
top_4_currency_names_except_first_two_three = dx[(dx['Symbol']!= 'BTC') & (dx['Symbol']!= 'ETH') & (dx['Symbol']!= 'USDT')].groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(4).index

data_top_4_currencies = dx[dx['Symbol'].isin(top_4_currency_names)]
top_4_currencies_after_BTC = dx[dx['Symbol'].isin(top_4_currency_names_except_first)]
top_4_currencies_after_BTC_ETH = dx[dx['Symbol'].isin(top_4_currency_names_except_first_two)]
top_4_currencies_after_BTC_ETH_USDT = dx[dx['Symbol'].isin(top_4_currency_names_except_first_two_three)]

# %%
plt.figure(figsize=(20,25))

plt.subplot(4,1,1)
sns.lineplot(data=data_top_4_currencies, x="CloseTime", y="ClosePrice", hue='Symbol')
plt.title("Closing Prices of Top 4 Cryptocurrencies", fontsize=20)
plt.legend(loc='upper left')

plt.subplot(4,1,2)
sns.lineplot(data=top_4_currencies_after_BTC, x="Date", y="Close", hue='Symbol')
plt.title("Closing Prices of Top 4 Cryptocurrencies except BTC", fontsize=20)
plt.legend(loc='upper left')

plt.subplot(4,1,3)
sns.lineplot(data=top_4_currencies_after_BTC_ETH,x="Date", y="Close", hue='Symbol')
plt.title("Closing Prices of Top 4 Cryptocurrencies except BTC & ETH", fontsize=20)
plt.legend(loc='upper left')

plt.subplot(4,1,4)
sns.lineplot(data=top_4_currencies_after_BTC_ETH_USDT,x="Date", y="Close", hue='Symbol')
plt.title("Closing Prices of Top 4 Cryptocurrencies except BTC, ETH & USDT", fontsize=20)
plt.legend(loc='upper left')

plt.show()

# %%
plt.figure(figsize=[18,5])
sb.lineplot(data=data_top_4_currencies, x="Date", y="ClosePrice", hue='Symbol')
plt.title("Closing Prices of Top 4 Cryptocurrencies", fontsize=20)
plt.legend(loc='upper left')

# %%
plt.figure(figsize=[18,5])
sb.lineplot(data=data_top_4_currencies, x="Year", y="ClosePrice", hue='Symbol')
plt.title("Closing Prices of Top 4 Cryptocurrencies", fontsize=20)
plt.legend(loc='upper left')

# %%
coins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43747 entries, 0 to 4620
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CloseTime   43747 non-null  datetime64[ns]
#  1   OpenPrice   43747 non-null  float64
#  2   HighPrice   43747 non-null  float64
#  3   LowPrice    43747 non-null  float64
#  4   ClosePrice  43747 non-null  float64
#  5   volume      43747 non-null  float64
#  6   MarketCap   43747 non-null  float64
#  7   Symbol      43747 non-null  object
#  8   Year        43747 non-null  int64
#  9   Month       43747 non-null  int64
# dtypes: datetime64[ns](1), float64(6), int64(2), object(1)
# memory usage: 4.7+ MB

# %%
sb.lineplot(data=coins, x="Year", y="OpenPrice")
# Out:
# C:\Users\DELL 5480\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\_core.py:1057: FutureWarning:
#
# reindexing with a non-unique Index is deprecated and will raise in a future version.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [98], in <cell line: 1>()
# ----> 1 sb.lineplot(data=coins, x="Year", y="OpenPrice")
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\relational.py:471, in _LinePlotter.plot(self, ax, kws)
#     469 # Loop over the semantic subsets and add to the plot
#     470 grouping_vars = "hue", "size", "style"
# --> 471 for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     473     if self.sort:
#     474         sort_vars = ["units", "x", "y"]
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\_core.py:983, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data)
#     978 grouping_vars = [
#     979     var for var in grouping_vars if var in self.variables
#     980 ]
#     982 if from_comp_data:
# --> 983     data = self.comp_data
#     984 else:
#     985     data = self.plot_data
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\_core.py:1057, in VectorPlotter.comp_data(self)
#    1055     orig = self.plot_data[var].dropna()
#    1056 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1059 if axis.get_scale() == "log":
#    1060     comp_col = np.log10(comp_col)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
# -> 1690     self._setitem_single_block(indexer, value, name)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexing.py:1929, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    1923     indexer = maybe_convert_ix(*indexer)  # e.g. test_setitem_frame_align
#    1925 if (isinstance(value, ABCSeries) and name != "iloc") or isinstance(value, dict):
#    1926     # TODO(EA): ExtensionBlock.setitem this causes issues with
#    1927     # setting for extensionarrays that store dicts. Need to decide
#    1928     # if it's worth supporting that.
# -> 1929     value = self._align_series(indexer, Series(value))
#    1931 elif isinstance(value, ABCDataFrame) and name != "iloc":
#    1932     value = self._align_frame(indexer, value)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexing.py:2091, in _iLocIndexer._align_series(self, indexer, ser, multiindex_indexer)
#    2089 if obj.ndim == 2 and is_empty_indexer(indexer[0], ser._values):
#    2090     return ser._values.copy()
# -> 2091 ser = ser.reindex(obj.axes[0][indexer[0]], copy=True)._values
#    2093 # single indexer
#    2094 if len(indexer) > 1 and not multiindex_indexer:
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\series.py:4672, in Series.reindex(self, *args, **kwargs)
#    4668         raise TypeError(
#    4669             "'index' passed as both positional and keyword argument"
#    4670         )
#    4671     kwargs.update({"index": index})
# -> 4672 return super().reindex(**kwargs)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\generic.py:4966, in NDFrame.reindex(self, *args, **kwargs)
#    4963     return self._reindex_multi(axes, copy, fill_value)
#    4965 # perform the reindex on the axes
# -> 4966 return self._reindex_axes(
#    4967     axes, level, limit, tolerance, method, fill_value, copy
#    4968 ).__finalize__(self, method="reindex")
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\generic.py:4986, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    4981 new_index, indexer = ax.reindex(
#    4982     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    4983 )
#    4985 axis = self._get_axis_number(a)
# -> 4986 obj = obj._reindex_with_indexers(
#    4987     {axis: [new_index, indexer]},
#    4988     fill_value=fill_value,
#    4989     copy=copy,
#    4990     allow_dups=False,
#    4991 )
#    4992 # If we've made a copy once, no need to make another one
#    4993 copy = False
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\generic.py:5032, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5029     indexer = ensure_platform_int(indexer)
#    5031 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5032 new_data = new_data.reindex_indexer(
#    5033     index,
#    5034     indexer,
#    5035     axis=baxis,
#    5036     fill_value=fill_value,
#    5037     allow_dups=allow_dups,
#    5038     copy=copy,
#    5039 )
#    5040 # If we've made a copy once, no need to make another one
#    5041 copy = False
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\internals\managers.py:679, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, consolidate, only_slice, use_na_proxy)
#     677 # some axes don't allow reindexing with dups
#     678 if not allow_dups:
# --> 679     self.axes[axis]._validate_can_reindex(indexer)
#     681 if axis >= self.ndim:
#     682     raise IndexError("Requested axis not found in manager")
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexes\base.py:4107, in Index._validate_can_reindex(self, indexer)
#    4105 # trying to reindex on an axis with duplicates
#    4106 if not self._index_as_unique and len(indexer):
# -> 4107     raise ValueError("cannot reindex on an axis with duplicate labels")
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
coins['Symbol'].unique()
# Out:
# array(['BTC', 'ETH', 'ADA', 'XRP', 'USDT', 'MATIC', 'USDC', 'SHIB', 'FTM',
#        'UMA'], dtype=object)

# %%
# In order to visualize the measurement distribution of CO and NOx over the years, we need to split the main dataframe 
# into different dataframes because visualizing everything at once would be clumsy.

# let's split the dataset into different sets to aid easy visualization

top_4_coin_names = coins[coins['Symbol'].isin(['BTC', 'ETH', 'ADA', 'XRP', 'USDT', 'MATIC', 'USDC', 'SHIB', 'FTM', 'UMA'])]

top_4_coin_names_except_BTC = coins[coins['Symbol'].isin(['ETH', 'ADA', 'XRP', 'USDT', 'MATIC', 'USDC', 'SHIB', 'FTM','UMA'])]
                                 
top_4_coin_names_except_BTC_ETH = coins[coins['Symbol'].isin(['ADA', 'XRP', 'USDT', 'MATIC', 'USDC', 'SHIB', 'FTM','UMA'])]
                                  
top_4_coin_names_except_BTC_ETH_USDT = coins[coins['Symbol'].isin(['ADA', 'XRP', 'MATIC', 'USDC', 'SHIB', 'FTM','UMA'])]

# %%
plt.figure(figsize=(20, 25))

plt.subplot(4, 1, 1)
sb.lineplot(data=top_4_coin_names, x='ClosePrice', y='CloseTime', hue='Symbol')
plt.title('Closing Prices of Top 4 Cryptocurrencies', fontsize=20)
plt.legend(loc = 'upper left')

plt.subplot(4, 1, 2)
sb.lineplot(data=top_4_coin_names_except_BTC, x='ClosePrice', y='CloseTime', hue='Symbol')
plt.title('Closing Prices of Top 4 Cryptocurrencies except BTC', fontsize=20)
plt.legend(loc='upper left')

plt.subplot(4, 1, 3)
sb.lineplot(data=top_4_coin_names_except_BTC_ETH, x='CloseTime', y='ClosePrice', hue='Symbol')
plt.title('Closing Prices of Top 4 Cryptocurrencies except BTC & ETH', fontsize=20)
plt.legend(loc='upper left')

plt.subplot(4, 1, 4)
sb.lineplot(data=top_4_coin_names_except_BTC_ETH_USDT, x='CloseTime', y='ClosePrice', hue='Symbol')
plt.title('Closing Prices of Top 4 Cryptocurrencies except BTC, ETH, & USDT', fontsize=20)
plt.legend(loc= 'upper left')

plt.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [88], in <cell line: 4>()
#       1 plt.figure(figsize=(20, 25))
#       3 plt.subplot(4, 1, 1)
# ----> 4 sb.lineplot(data=top_4_coin_names, x='ClosePrice', y='CloseTime', hue='Symbol')
#       5 plt.title('Closing Prices of Top 4 Cryptocurrencies', fontsize=20)
#       6 plt.legend(loc = 'upper left')
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\relational.py:710, in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     706     return ax
#     708 p._attach(ax)
# --> 710 p.plot(ax, kwargs)
#     711 return ax
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\relational.py:471, in _LinePlotter.plot(self, ax, kws)
#     469 # Loop over the semantic subsets and add to the plot
#     470 grouping_vars = "hue", "size", "style"
# --> 471 for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     473     if self.sort:
#     474         sort_vars = ["units", "x", "y"]
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\_core.py:983, in VectorPlotter.iter_data(self, grouping_vars, reverse, from_comp_data)
#     978 grouping_vars = [
#     979     var for var in grouping_vars if var in self.variables
#     980 ]
#     982 if from_comp_data:
# --> 983     data = self.comp_data
#     984 else:
#     985     data = self.plot_data
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\seaborn\_core.py:1057, in VectorPlotter.comp_data(self)
#    1055     orig = self.plot_data[var].dropna()
#    1056 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1059 if axis.get_scale() == "log":
#    1060     comp_col = np.log10(comp_col)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexing.py:716, in _LocationIndexer.__setitem__(self, key, value)
#     713 self._has_valid_setitem_indexer(key)
#     715 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexing.py:1690, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1688     self._setitem_with_indexer_split_path(indexer, value, name)
#    1689 else:
# -> 1690     self._setitem_single_block(indexer, value, name)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexing.py:1938, in _iLocIndexer._setitem_single_block(self, indexer, value, name)
#    1935 self.obj._check_is_chained_assignment_possible()
#    1937 # actually do the set
# -> 1938 self.obj._mgr = self.obj._mgr.setitem(indexer=indexer, value=value)
#    1939 self.obj._maybe_update_cacher(clear=True, inplace=True)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\internals\managers.py:337, in BaseBlockManager.setitem(self, indexer, value)
#     331 def setitem(self: T, indexer, value) -> T:
#     332     """
#     333     Set values with indexer.
#     334
#     335     For SingleBlockManager, this backs s[indexer] = value
#     336     """
# --> 337     return self.apply("setitem", indexer=indexer, value=value)
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\internals\blocks.py:944, in Block.setitem(self, indexer, value)
#     941     values = values.T
#     943 # length checking
# --> 944 check_setitem_lengths(indexer, value, values)
#     946 if is_empty_indexer(indexer, arr_value):
#     947     # GH#8669 empty indexers, test_loc_setitem_boolean_mask_allfalse
#     948     pass
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexers\utils.py:176, in check_setitem_lengths(indexer, value, values)
#     170         indexer = np.array(indexer)
#     171     if not (
#     172         isinstance(indexer, np.ndarray)
#     173         and indexer.dtype == np.bool_
#     174         and indexer.sum() == len(value)
#     175     ):
# --> 176         raise ValueError(
#     177             "cannot set using a list-like indexer "
#     178             "with a different length than the value"
#     179         )
#     180 if not len(indexer):
#     181     no_op = True
#
# ValueError: cannot set using a list-like indexer with a different length than the value

# %%
# Finding top 5 cryptocurrencies by market cap
plt.figure(figsize=[18,5])
ax = coins.groupby(['Symbol'])['MarketCap'].last().sort_values(ascending=False).head(5).sort_values().plot(kind='barh')
ax.set_xlabel('Market Cap (in billion USD)')
ax.ticklabel_format(style='plain', axis='x')
plt.title('Top 5 Cryptocurrencies by Market Cap', fontsize = 15)
plt.show()

# %%
coins.index.is_unique
# Out:
# False

# %%
coins.index.duplicated()
# Out:
# array([False, False, False, ...,  True,  True,  True])

# %%
coins_df = coins.copy()

# %%
df.loc[~df.index.duplicated(), :]

# %%
coins_df.loc[~coins_df.index.duplicated(), :]
# Out:
#                CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0    2021-04-20 10:00:00   54461.85   55479.62  54284.33    54940.10
# 1    2021-04-20 12:00:00   54940.10   56466.32  54884.22    56348.13
# 2    2021-04-20 14:00:00   56356.72   56403.98  55661.65    56379.84
# 3    2021-04-20 16:00:00   56406.02   56542.92  54700.00    55355.58
# 4    2021-04-20 18:00:00   55384.65   56010.61  55155.76    55942.70
# ...                  ...        ...        ...       ...         ...
# 5995 2022-09-02 00:00:00   20095.00   20174.00  20061.00    20128.00
# 5996 2022-09-02 02:00:00   20133.00   20133.00  20016.00    20048.00
# 5997 2022-09-02 04:00:00   20048.00   20235.00  19957.00    20161.00
# 5998 2022-09-02 06:00:00   20158.00   20295.00  20075.00    20125.00
# 5999 2022-09-02 08:00:00   20121.00   20132.00  20039.00    20122.00
#
#           volume     MarketCap Symbol  Year  Month
# 0     420.173397  2.311098e+07    BTC  2021      4
# 1     524.660874  2.932419e+07    BTC  2021      4
# 2     408.564245  2.290104e+07    BTC  2021      4
# 3     646.185067  3.587516e+07    BTC  2021      4
# 4     386.479547  2.148352e+07    BTC  2021      4
# ...          ...           ...    ...   ...    ...
# 5995   81.950392  1.647610e+06    BTC  2022      9
# 5996  112.853307  2.264364e+06    BTC  2022      9
# 5997   82.271167  1.653513e+06    BTC  2022      9
# 5998  121.282143  2.449675e+06    BTC  2022      9
# 5999   79.069175  1.587175e+06    BTC  2022      9
#
# [6000 rows x 10 columns]

# %%
coins_df
# Out:
#                CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0    2021-04-20 10:00:00   54461.85   55479.62  54284.33    54940.10
# 1    2021-04-20 12:00:00   54940.10   56466.32  54884.22    56348.13
# 2    2021-04-20 14:00:00   56356.72   56403.98  55661.65    56379.84
# 3    2021-04-20 16:00:00   56406.02   56542.92  54700.00    55355.58
# 4    2021-04-20 18:00:00   55384.65   56010.61  55155.76    55942.70
# ...                  ...        ...        ...       ...         ...
# 4616 2022-08-31 20:00:00       2.72       2.75      2.72        2.75
# 4617 2022-09-01 02:00:00       2.78       2.78      2.78        2.78
# 4618 2022-09-01 06:00:00       2.75       2.75      2.75        2.75
# 4619 2022-09-01 08:00:00       2.71       2.71      2.71        2.71
# 4620 2022-09-01 14:00:00       2.72       2.72      2.72        2.72
#
#           volume     MarketCap Symbol  Year  Month
# 0     420.173397  2.311098e+07    BTC  2021      4
# 1     524.660874  2.932419e+07    BTC  2021      4
# 2     408.564245  2.290104e+07    BTC  2021      4
# 3     646.185067  3.587516e+07    BTC  2021      4
# 4     386.479547  2.148352e+07    BTC  2021      4
# ...          ...           ...    ...   ...    ...
# 4616   51.000447  1.390095e+02    UMA  2022      8
# 4617   96.147878  2.672911e+02    UMA  2022      9
# 4618   52.393939  1.440833e+02    UMA  2022      9
# 4619  148.532765  4.025238e+02    UMA  2022      9
# 4620    9.551507  2.598010e+01    UMA  2022      9
#
# [43747 rows x 10 columns]

# %%
coins
# Out:
#                CloseTime  OpenPrice  HighPrice  LowPrice  ClosePrice  \
# 0    2021-04-20 10:00:00   54461.85   55479.62  54284.33    54940.10
# 1    2021-04-20 12:00:00   54940.10   56466.32  54884.22    56348.13
# 2    2021-04-20 14:00:00   56356.72   56403.98  55661.65    56379.84
# 3    2021-04-20 16:00:00   56406.02   56542.92  54700.00    55355.58
# 4    2021-04-20 18:00:00   55384.65   56010.61  55155.76    55942.70
# ...                  ...        ...        ...       ...         ...
# 4616 2022-08-31 20:00:00       2.72       2.75      2.72        2.75
# 4617 2022-09-01 02:00:00       2.78       2.78      2.78        2.78
# 4618 2022-09-01 06:00:00       2.75       2.75      2.75        2.75
# 4619 2022-09-01 08:00:00       2.71       2.71      2.71        2.71
# 4620 2022-09-01 14:00:00       2.72       2.72      2.72        2.72
#
#           volume     MarketCap Symbol  Year  Month
# 0     420.173397  2.311098e+07    BTC  2021      4
# 1     524.660874  2.932419e+07    BTC  2021      4
# 2     408.564245  2.290104e+07    BTC  2021      4
# 3     646.185067  3.587516e+07    BTC  2021      4
# 4     386.479547  2.148352e+07    BTC  2021      4
# ...          ...           ...    ...   ...    ...
# 4616   51.000447  1.390095e+02    UMA  2022      8
# 4617   96.147878  2.672911e+02    UMA  2022      9
# 4618   52.393939  1.440833e+02    UMA  2022      9
# 4619  148.532765  4.025238e+02    UMA  2022      9
# 4620    9.551507  2.598010e+01    UMA  2022      9
#
# [43747 rows x 10 columns]

# %%
coins_df.flags.allows_duplicate_labels = False
# Out:
# ---------------------------------------------------------------------------
# DuplicateLabelError                       Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
# ----> 1 coins_df.flags.allows_duplicate_labels = False
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\flags.py:92, in Flags.allows_duplicate_labels(self, value)
#      90 if not value:
#      91     for ax in obj.axes:
# ---> 92         ax._maybe_check_unique()
#      94 self._allows_duplicate_labels = value
#
# File ~\anaconda3\envs\StarNPMS\lib\site-packages\pandas\core\indexes\base.py:715, in Index._maybe_check_unique(self)
#     712 duplicates = self._format_duplicate_message()
#     713 msg += f"\n{duplicates}"
# --> 715 raise DuplicateLabelError(msg)
#
# DuplicateLabelError: Index has duplicates.
#                                                positions
# label
# 0      [0, 6000, 12000, 15277, 21277, 26520, 31123, 3...
# 1      [1, 6001, 12001, 15278, 21278, 26521, 31124, 3...
# 2      [2, 6002, 12002, 15279, 21279, 26522, 31125, 3...
# 3      [3, 6003, 12003, 15280, 21280, 26523, 31126, 3...
# 4      [4, 6004, 12004, 15281, 21281, 26524, 31127, 3...
# ...                                                  ...
# 5995                         [5995, 11995, 21272, 37118]
# 5996                         [5996, 11996, 21273, 37119]
# 5997                         [5997, 11997, 21274, 37120]
# 5998                         [5998, 11998, 21275, 37121]
# 5999                         [5999, 11999, 21276, 37122]
#
# [6000 rows x 1 columns]

# %%
# use a barchart to view the coin performance
# create a barchart using seaborn

sb.set_style('whitegrid')
bar,ax = plt.subplots(figsize=(8,6))
ax = sb.barplot(x='ClosePrice', y='Symbol', data=coins, ci=None, color='grey', orient='h')
ax.set_title('Crypto Prices in USD', fontsize=25)
ax.set(xscale = 'log') # set scale to view others
ax.set_xlabel('Crypto', fontsize = 20)
ax.set_ylabel(None, fontsize = 20)
ax.tick_params(axis='x', labelsize = 15)
ax.tick_params(axis='y', labelsize = 15)
plt.savefig('cryptoprice.svg')

# %%
# check the mean performance of all
df = coins.groupby('Symbol').agg({'ClosePrice':np.mean, 'OpenPrice':np.mean, 'HighPrice':np.mean, 
                                  'LowPrice':np.mean}).reset_index()
fig = px.line(df, x='Symbol', y=['ClosePrice', 'HighPrice', 'LowPrice', 'OpenPrice'])
fig.update_layout(autosize=False,
                 width=400,
                 height=600,
                 template='plotly_dark',
                 yaxis_title = 'Price',
                 title = 'Mean CHCL Prices in Crypto currencies',
                 hovermode='x',
                 title_x=0.5
)
fig.update_yaxes(# the y axis is in dollars
    tickprefix='$', showgrid=True
)

# %%
coins.sample(10)
# Out:
#                CloseTime   OpenPrice   HighPrice    LowPrice  ClosePrice  \
# 3919 2022-03-13 00:00:00  2587.66000  2593.66000  2563.58000  2569.16000
# 3262 2022-01-08 18:00:00     1.00024     1.00074     0.99980     1.00043
# 1189 2021-07-28 10:00:00  2297.93000  2317.16000  2278.20000  2307.20000
# 1906 2021-09-26 06:00:00     0.92577     0.92680     0.91664     0.92091
# 1045 2021-07-06 10:00:00     1.00003     1.00199     0.99993     1.00013
# 1819 2021-09-18 22:00:00  3446.69000  3446.97000  3378.00000  3389.36000
# 2417 2022-02-28 04:00:00     1.45781     1.45781     1.43384     1.44650
# 1985 2021-10-24 18:00:00    11.32000    11.50000    11.27000    11.50000
# 2673 2022-01-26 22:00:00     1.00104     1.00118     1.00031     1.00041
# 781  2021-08-21 10:00:00     0.99992     1.00051     0.99969     1.00051
#
#              volume     MarketCap Symbol  Year  Month
# 3919     199.762489  5.154358e+05    ETH  2022      3
# 3262  316470.554260  3.164379e+05   USDC  2022      1
# 1189    4605.783037  1.057468e+07    ETH  2021      7
# 1906  354837.978051  3.268685e+05    XRP  2021      9
# 1045  707353.881210  7.085495e+05   USDC  2021      7
# 1819    1113.631732  3.786284e+06    ETH  2021      9
# 2417    5284.415769  7.648122e+03  MATIC  2022      2
# 1985     462.730509  5.284120e+03    UMA  2021     10
# 2673   87667.609610  8.773775e+04   USDT  2022      1
# 781   282329.570770  2.824558e+05   USDT  2021      8

# %%
OpenPrice = This is when the market opens on the same day
ClosePrice = This is when the market closes on the same physical day

# %%
coins.to_csv('crypto_coins.csv', index=False)
